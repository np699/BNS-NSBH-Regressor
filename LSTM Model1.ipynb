# %% [markdown]
# # Imports

# %%
from keras.regularizers import l1_l2
from keras.layers import BatchNormalization
from keras.layers import Bidirectional
from sklearn.utils import shuffle
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.constraints import max_norm
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
import tensorflow as tf
from joblib import dump, load
from tensorflow.keras import losses

# %% [markdown]
# # Input data (mass ejecta)

# %%
# Load the data
lightCurve = pd.read_csv("/Users/np699/Library/CloudStorage/OneDrive-DrexelUniversity/Untitled Folder/Forecaster/lightcurveDataCom7988.csv")
features = pd.read_csv("/Users/np699/Library/CloudStorage/OneDrive-DrexelUniversity/Untitled Folder/Forecaster/featureDataCom7988_ejectaA.csv")


# Drop unnecessary columns from the features dataframe
features = features.drop(["simulation_id", 'far', 'snr'], axis=1)

# Filter the light curve data
filtered_df = lightCurve[lightCurve['filter'].isin(['ztfg', 'ztfr', 'ztfi'])].copy()
filtered_df = filtered_df[['filter', 'mag']]

num_light_curves = features.shape[0]

# Ensure the data is in the correct order
filter_order = ['ztfg', 'ztfr', 'ztfi']
filtered_df['filter'] = pd.Categorical(filtered_df['filter'], categories=filter_order, ordered=True)
filtered_df = filtered_df.sort_index()

# Consistency check
total_points = len(filtered_df)
if total_points % (num_light_curves * len(filter_order)) != 0:
    raise ValueError("The number of data points is not divisible by the number of light curves times the number of filters.")

num_time_points = total_points // (num_light_curves * len(filter_order))

# Reshape the data
y = np.empty((num_light_curves, num_time_points * len(filter_order)), dtype=filtered_df['mag'].dtype)
ztfg_mags = filtered_df[filtered_df['filter'] == 'ztfg']['mag'].values.reshape(num_light_curves, num_time_points)
ztfr_mags = filtered_df[filtered_df['filter'] == 'ztfr']['mag'].values.reshape(num_light_curves, num_time_points)
ztfi_mags = filtered_df[filtered_df['filter'] == 'ztfi']['mag'].values.reshape(num_light_curves, num_time_points)

# Populate reshaped array
for i in range(num_time_points):
    y[:, i * 3 + 0] = ztfg_mags[:, i]
    y[:, i * 3 + 1] = ztfr_mags[:, i]
    y[:, i * 3 + 2] = ztfi_mags[:, i]

# Time array
t_min = 0.1
t_max = 14.0
dt = 0.2
time_single = np.linspace(t_min, t_max, num_time_points)

# Standardize the feature data
feature_scaler = StandardScaler()
X = feature_scaler.fit_transform(features)

# Standardize the target data
target_scaler = StandardScaler()
y = target_scaler.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Reshape y data for LSTM input
y_train_reshaped = y_train.reshape((y_train.shape[0], num_time_points, len(filter_order)))
y_test_reshaped = y_test.reshape((y_test.shape[0], num_time_points, len(filter_order)))

# Reshape X data for LSTM input
X_train_reshaped = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %% [markdown]
# # Model

# %%
# Define the LSTM model
model = Sequential()

# First Bidirectional LSTM Layer with Batch Normalization and Dropout
model.add(Bidirectional(LSTM(150, activation='relu', return_sequences=True,
                             kernel_regularizer=l1_l2(l1=0.001, l2=0.01),
                             kernel_constraint=max_norm(3.0),
                        input_shape=(1, X_train.shape[1]))))
model.add(BatchNormalization())
model.add(Dropout(0.1))

# Second Bidirectional LSTM Layer with Batch Normalization
model.add(Bidirectional(LSTM(100, activation='relu', return_sequences=False,
                             kernel_regularizer=l1_l2(l1=0.001, l2=0.01),
                             kernel_constraint=max_norm(3.0)
                             )))
model.add(BatchNormalization())
model.add(Dropout(0.1))

# Dense output layer
model.add(Dense(213))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training

# %%
# Compile the model with a lower learning rate and gradient clipping
optimizer = Adam(learning_rate=0.0003, clipnorm=1.0)  # Only clipnorm is used
model.compile(optimizer=optimizer, loss='mse')

# Implement early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-6)

# Train the model
history = model.fit(X_train_reshaped, y_train, 
                    epochs=300, batch_size=64, validation_split=0.3, 
                    verbose=1, callbacks=[early_stopping, lr_reduction])

# Save the trained model
#dump(model, 'Com7988_ejectaA.joblib')
# Out:
# Epoch 1/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 18.4642 - val_loss: 13.2418 - learning_rate: 3.0000e-04
# Epoch 2/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 11.3997 - val_loss: 8.4236 - learning_rate: 3.0000e-04
# Epoch 3/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.8933 - val_loss: 5.2031 - learning_rate: 3.0000e-04
# Epoch 4/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9128 - val_loss: 3.1657 - learning_rate: 3.0000e-04
# Epoch 5/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.0606 - val_loss: 1.9765 - learning_rate: 3.0000e-04
# Epoch 6/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.0436 - val_loss: 1.3763 - learning_rate: 3.0000e-04
# Epoch 7/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.5881 - val_loss: 1.1114 - learning_rate: 3.0000e-04
# Epoch 8/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4387 - val_loss: 0.9288 - learning_rate: 3.0000e-04
# Epoch 9/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3644 - val_loss: 0.7679 - learning_rate: 3.0000e-04
# Epoch 10/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3279 - val_loss: 0.6146 - learning_rate: 3.0000e-04
# Epoch 11/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2941 - val_loss: 0.4955 - learning_rate: 3.0000e-04
# Epoch 12/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2740 - val_loss: 0.3537 - learning_rate: 3.0000e-04
# Epoch 13/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2593 - val_loss: 0.2815 - learning_rate: 3.0000e-04
# Epoch 14/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2469 - val_loss: 0.2507 - learning_rate: 3.0000e-04
# Epoch 15/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2394 - val_loss: 0.2271 - learning_rate: 3.0000e-04
# Epoch 16/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2292 - val_loss: 0.2168 - learning_rate: 3.0000e-04
# Epoch 17/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2274 - val_loss: 0.1975 - learning_rate: 3.0000e-04
# Epoch 18/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2203 - val_loss: 0.1904 - learning_rate: 3.0000e-04
# Epoch 19/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2027 - val_loss: 0.1939 - learning_rate: 3.0000e-04
# Epoch 20/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2062 - val_loss: 0.1909 - learning_rate: 3.0000e-04
# Epoch 21/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2009 - val_loss: 0.1839 - learning_rate: 3.0000e-04
# Epoch 22/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2033 - val_loss: 0.1762 - learning_rate: 3.0000e-04
# Epoch 23/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1966 - val_loss: 0.1762 - learning_rate: 3.0000e-04
# Epoch 24/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1906 - val_loss: 0.1748 - learning_rate: 3.0000e-04
# Epoch 25/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1861 - val_loss: 0.1713 - learning_rate: 3.0000e-04
# Epoch 26/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1967 - val_loss: 0.1726 - learning_rate: 3.0000e-04
# Epoch 27/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1958 - val_loss: 0.1697 - learning_rate: 3.0000e-04
# Epoch 28/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1863 - val_loss: 0.1694 - learning_rate: 3.0000e-04
# Epoch 29/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1914 - val_loss: 0.1719 - learning_rate: 3.0000e-04
# Epoch 30/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1891 - val_loss: 0.1715 - learning_rate: 3.0000e-04
# Epoch 31/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1804 - val_loss: 0.1663 - learning_rate: 3.0000e-04
# Epoch 32/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1884 - val_loss: 0.1673 - learning_rate: 3.0000e-04
# Epoch 33/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1804 - val_loss: 0.1645 - learning_rate: 3.0000e-04
# Epoch 34/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1911 - val_loss: 0.1630 - learning_rate: 3.0000e-04
# Epoch 35/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1803 - val_loss: 0.1654 - learning_rate: 3.0000e-04
# Epoch 36/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1769 - val_loss: 0.1621 - learning_rate: 3.0000e-04
# Epoch 37/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1765 - val_loss: 0.1590 - learning_rate: 3.0000e-04
# Epoch 38/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1706 - val_loss: 0.1611 - learning_rate: 3.0000e-04
# Epoch 39/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1708 - val_loss: 0.1640 - learning_rate: 3.0000e-04
# Epoch 40/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1731 - val_loss: 0.1613 - learning_rate: 3.0000e-04
# Epoch 41/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1711 - val_loss: 0.1580 - learning_rate: 3.0000e-04
# Epoch 42/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1758 - val_loss: 0.1609 - learning_rate: 3.0000e-04
# Epoch 43/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1696 - val_loss: 0.1577 - learning_rate: 3.0000e-04
# Epoch 44/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1778 - val_loss: 0.1643 - learning_rate: 3.0000e-04
# Epoch 45/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1774 - val_loss: 0.1602 - learning_rate: 3.0000e-04
# Epoch 46/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1766 - val_loss: 0.1603 - learning_rate: 3.0000e-04
# Epoch 47/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1755 - val_loss: 0.1554 - learning_rate: 3.0000e-04
# Epoch 48/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1749 - val_loss: 0.1539 - learning_rate: 3.0000e-04
# Epoch 49/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1712 - val_loss: 0.1562 - learning_rate: 3.0000e-04
# Epoch 50/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1734 - val_loss: 0.1558 - learning_rate: 3.0000e-04
# Epoch 51/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1739 - val_loss: 0.1543 - learning_rate: 3.0000e-04
# Epoch 52/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1670 - val_loss: 0.1532 - learning_rate: 3.0000e-04
# Epoch 53/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1651 - val_loss: 0.1543 - learning_rate: 3.0000e-04
# Epoch 54/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1712 - val_loss: 0.1534 - learning_rate: 3.0000e-04
# Epoch 55/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1670 - val_loss: 0.1540 - learning_rate: 3.0000e-04
# Epoch 56/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1733 - val_loss: 0.1522 - learning_rate: 3.0000e-04
# Epoch 57/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1688 - val_loss: 0.1509 - learning_rate: 3.0000e-04
# Epoch 58/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1728 - val_loss: 0.1530 - learning_rate: 3.0000e-04
# Epoch 59/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1703 - val_loss: 0.1524 - learning_rate: 3.0000e-04
# Epoch 60/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1729 - val_loss: 0.1503 - learning_rate: 3.0000e-04
# Epoch 61/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1668 - val_loss: 0.1562 - learning_rate: 3.0000e-04
# Epoch 62/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1625 - val_loss: 0.1517 - learning_rate: 3.0000e-04
# Epoch 63/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1660 - val_loss: 0.1506 - learning_rate: 3.0000e-04
# Epoch 64/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1607 - val_loss: 0.1511 - learning_rate: 3.0000e-04
# Epoch 65/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1733 - val_loss: 0.1496 - learning_rate: 3.0000e-04
# Epoch 66/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1609 - val_loss: 0.1522 - learning_rate: 3.0000e-04
# Epoch 67/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1707 - val_loss: 0.1523 - learning_rate: 3.0000e-04
# Epoch 68/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1685 - val_loss: 0.1512 - learning_rate: 3.0000e-04
# Epoch 69/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1688 - val_loss: 0.1492 - learning_rate: 3.0000e-04
# Epoch 70/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1768 - val_loss: 0.1494 - learning_rate: 3.0000e-04
# Epoch 71/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1740 - val_loss: 0.1513 - learning_rate: 3.0000e-04
# Epoch 72/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1623 - val_loss: 0.1493 - learning_rate: 3.0000e-04
# Epoch 73/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1632 - val_loss: 0.1518 - learning_rate: 3.0000e-04
# Epoch 74/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1679 - val_loss: 0.1517 - learning_rate: 3.0000e-04
# Epoch 75/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1685 - val_loss: 0.1406 - learning_rate: 1.5000e-04
# Epoch 76/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1539 - val_loss: 0.1428 - learning_rate: 1.5000e-04
# Epoch 77/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1619 - val_loss: 0.1415 - learning_rate: 1.5000e-04
# Epoch 78/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1542 - val_loss: 0.1403 - learning_rate: 1.5000e-04
# Epoch 79/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1629 - val_loss: 0.1404 - learning_rate: 1.5000e-04
# Epoch 80/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1572 - val_loss: 0.1406 - learning_rate: 1.5000e-04
# Epoch 81/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1544 - val_loss: 0.1403 - learning_rate: 1.5000e-04
# Epoch 82/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1592 - val_loss: 0.1402 - learning_rate: 1.5000e-04
# Epoch 83/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1531 - val_loss: 0.1405 - learning_rate: 1.5000e-04
# Epoch 84/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1578 - val_loss: 0.1405 - learning_rate: 1.5000e-04
# Epoch 85/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1609 - val_loss: 0.1403 - learning_rate: 1.5000e-04
# Epoch 86/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1582 - val_loss: 0.1398 - learning_rate: 1.5000e-04
# Epoch 87/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1714 - val_loss: 0.1438 - learning_rate: 1.5000e-04
# Epoch 88/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1654 - val_loss: 0.1396 - learning_rate: 1.5000e-04
# Epoch 89/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1601 - val_loss: 0.1413 - learning_rate: 1.5000e-04
# Epoch 90/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1652 - val_loss: 0.1380 - learning_rate: 1.5000e-04
# Epoch 91/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1583 - val_loss: 0.1393 - learning_rate: 1.5000e-04
# Epoch 92/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1532 - val_loss: 0.1390 - learning_rate: 1.5000e-04
# Epoch 93/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1535 - val_loss: 0.1387 - learning_rate: 1.5000e-04
# Epoch 94/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1585 - val_loss: 0.1387 - learning_rate: 1.5000e-04
# Epoch 95/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1647 - val_loss: 0.1379 - learning_rate: 1.5000e-04
# Epoch 96/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1543 - val_loss: 0.1392 - learning_rate: 1.5000e-04
# Epoch 97/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1549 - val_loss: 0.1400 - learning_rate: 1.5000e-04
# Epoch 98/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1559 - val_loss: 0.1395 - learning_rate: 1.5000e-04
# Epoch 99/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1657 - val_loss: 0.1386 - learning_rate: 1.5000e-04
# Epoch 100/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1546 - val_loss: 0.1426 - learning_rate: 1.5000e-04
# Epoch 101/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1532 - val_loss: 0.1345 - learning_rate: 7.5000e-05
# Epoch 102/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1548 - val_loss: 0.1348 - learning_rate: 7.5000e-05
# Epoch 103/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1533 - val_loss: 0.1349 - learning_rate: 7.5000e-05
# Epoch 104/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1494 - val_loss: 0.1347 - learning_rate: 7.5000e-05
# Epoch 105/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1486 - val_loss: 0.1351 - learning_rate: 7.5000e-05
# Epoch 106/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1540 - val_loss: 0.1365 - learning_rate: 7.5000e-05
# Epoch 107/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1490 - val_loss: 0.1327 - learning_rate: 3.7500e-05
# Epoch 108/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1491 - val_loss: 0.1339 - learning_rate: 3.7500e-05
# Epoch 109/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1519 - val_loss: 0.1325 - learning_rate: 3.7500e-05
# Epoch 110/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1452 - val_loss: 0.1319 - learning_rate: 3.7500e-05
# Epoch 111/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1502 - val_loss: 0.1324 - learning_rate: 3.7500e-05
# Epoch 112/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1515 - val_loss: 0.1321 - learning_rate: 3.7500e-05
# Epoch 113/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1491 - val_loss: 0.1318 - learning_rate: 3.7500e-05
# Epoch 114/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1437 - val_loss: 0.1319 - learning_rate: 3.7500e-05
# Epoch 115/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1529 - val_loss: 0.1331 - learning_rate: 3.7500e-05
# Epoch 116/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1543 - val_loss: 0.1318 - learning_rate: 3.7500e-05
# Epoch 117/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1530 - val_loss: 0.1324 - learning_rate: 3.7500e-05
# Epoch 118/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1493 - val_loss: 0.1318 - learning_rate: 3.7500e-05
# Epoch 119/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1631 - val_loss: 0.1312 - learning_rate: 1.8750e-05
# Epoch 120/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1491 - val_loss: 0.1311 - learning_rate: 1.8750e-05
# Epoch 121/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1518 - val_loss: 0.1311 - learning_rate: 1.8750e-05
# Epoch 122/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1538 - val_loss: 0.1312 - learning_rate: 1.8750e-05
# Epoch 123/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1459 - val_loss: 0.1309 - learning_rate: 1.8750e-05
# Epoch 124/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1506 - val_loss: 0.1309 - learning_rate: 1.8750e-05
# Epoch 125/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1530 - val_loss: 0.1310 - learning_rate: 1.8750e-05
# Epoch 126/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1479 - val_loss: 0.1309 - learning_rate: 1.8750e-05
# Epoch 127/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1484 - val_loss: 0.1310 - learning_rate: 1.8750e-05
# Epoch 128/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1496 - val_loss: 0.1307 - learning_rate: 1.8750e-05
# Epoch 129/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1519 - val_loss: 0.1307 - learning_rate: 1.8750e-05
# Epoch 130/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1426 - val_loss: 0.1309 - learning_rate: 1.8750e-05
# Epoch 131/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1461 - val_loss: 0.1310 - learning_rate: 1.8750e-05
# Epoch 132/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1452 - val_loss: 0.1305 - learning_rate: 1.8750e-05
# Epoch 133/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1476 - val_loss: 0.1310 - learning_rate: 1.8750e-05
# Epoch 134/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1519 - val_loss: 0.1309 - learning_rate: 1.8750e-05
# Epoch 135/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1539 - val_loss: 0.1309 - learning_rate: 1.8750e-05
# Epoch 136/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1426 - val_loss: 0.1308 - learning_rate: 1.8750e-05
# Epoch 137/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1475 - val_loss: 0.1308 - learning_rate: 1.8750e-05
# Epoch 138/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1423 - val_loss: 0.1303 - learning_rate: 9.3750e-06
# Epoch 139/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1537 - val_loss: 0.1303 - learning_rate: 9.3750e-06
# Epoch 140/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1496 - val_loss: 0.1304 - learning_rate: 9.3750e-06
# Epoch 141/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1510 - val_loss: 0.1304 - learning_rate: 9.3750e-06
# Epoch 142/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1493 - val_loss: 0.1306 - learning_rate: 9.3750e-06
# Epoch 143/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1477 - val_loss: 0.1303 - learning_rate: 9.3750e-06
# Epoch 144/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1474 - val_loss: 0.1302 - learning_rate: 4.6875e-06
# Epoch 145/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1441 - val_loss: 0.1301 - learning_rate: 4.6875e-06
# Epoch 146/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1471 - val_loss: 0.1302 - learning_rate: 4.6875e-06
# Epoch 147/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1516 - val_loss: 0.1301 - learning_rate: 4.6875e-06
# Epoch 148/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1526 - val_loss: 0.1302 - learning_rate: 4.6875e-06
# Epoch 149/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1502 - val_loss: 0.1300 - learning_rate: 4.6875e-06
# Epoch 150/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1573 - val_loss: 0.1300 - learning_rate: 4.6875e-06
# Epoch 151/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1525 - val_loss: 0.1299 - learning_rate: 2.3438e-06
# Epoch 152/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1460 - val_loss: 0.1299 - learning_rate: 2.3438e-06
# Epoch 153/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1531 - val_loss: 0.1299 - learning_rate: 2.3438e-06
# Epoch 154/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1430 - val_loss: 0.1299 - learning_rate: 2.3438e-06
# Epoch 155/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1444 - val_loss: 0.1299 - learning_rate: 2.3438e-06
# Epoch 156/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1410 - val_loss: 0.1299 - learning_rate: 2.3438e-06
# Epoch 157/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1439 - val_loss: 0.1299 - learning_rate: 1.1719e-06
# Epoch 158/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1499 - val_loss: 0.1300 - learning_rate: 1.1719e-06
# Epoch 159/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1468 - val_loss: 0.1299 - learning_rate: 1.1719e-06
# Epoch 160/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1453 - val_loss: 0.1299 - learning_rate: 1.1719e-06
# Epoch 161/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1455 - val_loss: 0.1299 - learning_rate: 1.1719e-06
# Epoch 162/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1487 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 163/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1486 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 164/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1446 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 165/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1552 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 166/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1394 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 167/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1518 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 168/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1446 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 169/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1477 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 170/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1490 - val_loss: 0.1298 - learning_rate: 1.0000e-06
# Epoch 171/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1471 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 172/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1523 - val_loss: 0.1300 - learning_rate: 1.0000e-06
# Epoch 173/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1532 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 174/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1446 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 175/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1463 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 176/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1484 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 177/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1456 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 178/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1465 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 179/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1484 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 180/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1453 - val_loss: 0.1299 - learning_rate: 1.0000e-06
# Epoch 181/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1439 - val_loss: 0.1299 - learning_rate: 1.0000e-06

# %% [markdown]
# # Predictions

# %%
# MC Dropout function for prediction with uncertainty
def predict_with_uncertainty(model, X, n_iter=1000):
    """
    Perform MC Dropout predictions with TensorFlow 2.x.
    
    Args:
    - model: The Keras model with dropout layers.
    - X: Input data to make predictions on.
    - n_iter: Number of forward passes to perform.
    
    Returns:
    - mean_preds: Mean predictions.
    - uncertainty: Standard deviation of predictions (uncertainty).
    """
    
    # Perform n_iter forward passes and collect the predictions
    preds = [model(X, training=True) for _ in range(n_iter)]  # Dropout active during inference
    preds = np.array(preds)
    
    # Calculate mean and standard deviation of the predictions
    mean_preds = preds.mean(axis=0)
    uncertainty = preds.std(axis=0)
    
    return mean_preds, uncertainty

# Perform MC Dropout to predict with uncertainty
n_mc_samples = 1000  # Number of forward passes
mean_preds, uncertainty = predict_with_uncertainty(model, X_test_reshaped, n_iter=n_mc_samples)

# Reshape the mean predictions to match the shape used during scaling (num_samples, num_time_points * num_filters)
mean_preds_flat = mean_preds.reshape(mean_preds.shape[0], num_time_points * len(filter_order))  
# Invert the standardization for the mean predictions
mean_preds_inverted = target_scaler.inverse_transform(mean_preds_flat).reshape(mean_preds.shape[0], num_time_points, len(filter_order))

# Reshape uncertainty to match mean_preds_inverted shape
uncertainty_reshaped = uncertainty.reshape(uncertainty.shape[0], num_time_points, len(filter_order))
# Evaluate the model using the mean predictions
print(mean_preds_flat.flatten().shape)
test_mse_mc = mean_squared_error(y_test.flatten(), mean_preds_flat.flatten())
test_r2_mc = r2_score(y_test.flatten(), mean_preds_flat.flatten())
print(test_mse_mc.shape)
print(f'Test MSE with MC Dropout: {test_mse_mc:.4f}, Test R² with MC Dropout: {test_r2_mc:.4f}')
mae = np.mean(np.abs(y_test.flatten() - mean_preds_flat.flatten()))
print(mae)

# Plot the learning curve
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve')
plt.legend()
plt.show()
# Out:
# (516312,)
# ()
# Test MSE with MC Dropout: 0.1194, Test R² with MC Dropout: 0.8868
# 0.25593686351639444

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Time points for plotting
time_points = np.tile(time_single, (X_test_reshaped.shape[0], 1))

# Invert the scaling for y_test to compare with predictions

y_test_inverted = target_scaler.inverse_transform(y_test.reshape(y_test.shape[0], -1)).reshape((y_test.shape[0], num_time_points, len(filter_order)))
mse_per_curve = np.mean((y_test_inverted - mean_preds_inverted) ** 2, axis=(1, 2))  # MSE for each light curve across all time points and filters

mse_target = 0.12
tolerance = 0.1  # Define a tolerance level to find light curves with MSE close to 3.6
selected_index = np.where(np.abs(mse_per_curve - mse_target) < tolerance)[0]  # Get the indices of the light curves that meet the condition

if len(selected_index) > 0:
    # Select the first light curve that matches the criteria
    example_idx = selected_index[0]

    # Step 3: Plot the selected light curve
    plt.figure(figsize=(10, 6))
    filter_names = ['ztfg', 'ztfr', 'ztfi']
    colors = {'ztfg': 'green', 'ztfr': 'red', 'ztfi': 'blue'}

    # Plot the ZTFg, ZTFr, and ZTFi filters separately for the selected light curve
    mean_curve = mean_preds_inverted[example_idx]
    true_curve = y_test_inverted[example_idx]

    # Loop over each filter
    for i, filter_name in enumerate(filter_names):
        plt.plot(time_single, mean_curve[:, i], label=f'Predicted {filter_name}', color=colors[filter_name])
        plt.fill_between(time_single, 
                         mean_curve[:, i] - 5 * uncertainty_reshaped[example_idx, :, i], 
                         mean_curve[:, i] + 5 * uncertainty_reshaped[example_idx, :, i], 
                         color=colors[filter_name], alpha=0.2, label=f'Uncertainty {filter_name}')

        # Plot the true values for comparison
        plt.plot(time_single, true_curve[:, i], '--', color=colors[filter_name], label=f'True {filter_name}')

    # Add labels and title
    plt.xlabel('Time (days)')
    plt.ylabel('Magnitude')
    plt.gca().invert_yaxis()  # Invert the y-axis for magnitude, since lower magnitude means brighter
    plt.title(f'Light Curve with MSE ~ {mse_target} (Light Curve Index: {example_idx})')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print(f"No light curve found with MSE close to {mse_target}.")

# %%
# Loop over each filter to calculate peak magnitudes and MSE per curve
for i, filter_name in enumerate(filter_names):
    # Step 1: Calculate the index of the minimum value (peak magnitude) for the current filter
    peak_indices = np.argmin(y_test_inverted[:, :, i], axis=1)  # Shape (num_samples,)

    # Step 2: Extract the corresponding predicted values at the peak magnitude indices
    peak_preds_filter = mean_preds_inverted[np.arange(mean_preds_inverted.shape[0]), peak_indices, i]

    # Step 3: Extract the corresponding true values at the peak magnitude indices
    peak_true_filter = y_test_inverted[np.arange(y_test_inverted.shape[0]), peak_indices, i]

    # Step 4: Calculate the MSE at the peak magnitude for each light curve
    mse_at_peak_filter = (peak_true_filter - peak_preds_filter) ** 2  # Shape (num_samples,)

    # Print the shapes to verify
    print(f"Filter: {filter_name}, MSE at peak shape: {mse_at_peak_filter.shape}")
    
    # Step 5: Now you can create histograms or perform further analysis based on mse_at_peak_filter
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Create a 3D histogram for the current filter
    hist, xedges, yedges = np.histogram2d(mse_at_peak_filter, peak_true_filter, bins=10, range=[[0, 1], [np.min(peak_true_filter), np.max(peak_true_filter)]])

    # Construct arrays for the 3D histogram bars
    xpos, ypos = np.meshgrid(xedges[:-1] + 0.5 * (xedges[1:] - xedges[:-1]),
                             yedges[:-1] + 0.5 * (yedges[1:] - yedges[:-1]), indexing="ij")

    xpos = xpos.ravel()
    ypos = ypos.ravel()
    zpos = 0

    # Set the width and depth for the bars
    dx = dy = 0.1 * np.ones_like(zpos)
    dz = hist.ravel()

    # Plot the bars
    ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average', color=colors[filter_names[i]], alpha=0.7)

    # Set labels and title
    ax.set_xlabel('MSE at Peak Magnitude')
    ax.set_ylabel('Peak Magnitude (min)')
    ax.set_zlabel('Number of Light Curves')
    ax.set_title(f'3D Histogram of MSE at Peak Magnitude for {filter_name}')

    plt.show()
# Out:
# Filter: ztfg, MSE at peak shape: (2424,)
# Filter: ztfr, MSE at peak shape: (2424,)
# Filter: ztfi, MSE at peak shape: (2424,)

# %%
# Loop over each filter and compute MSE at each time step
mse_vs_time = {}
filter_names = ['ztfg', 'ztfr', 'ztfi']
colors = {'ztfg': 'green', 'ztfr': 'red', 'ztfi': 'blue'}
y_test_reshaped = y_test.reshape(y_test.shape[0], num_time_points, len(filter_order)) 
print(y_test_reshaped.shape)
mean_preds_reshaped = mean_preds.reshape(mean_preds.shape[0], num_time_points, len(filter_order)) 
print(mean_preds_reshaped.shape)
for i, filter_name in enumerate(filter_names):
    # Calculate MSE at each time step (averaged across all light curves)
    mse_per_time_step = np.mean((y_test_reshaped[:,:,i] - mean_preds_reshaped[:,:,i]) ** 2, axis=0)  
    
    mse_vs_time[filter_name] = mse_per_time_step

plt.figure(figsize=(10, 6))

for filter_name in filter_names:
    plt.plot(time_single, mse_vs_time[filter_name], label=f'MSE for {filter_name}', color=colors[filter_name])

# Add labels and title
plt.xlabel('Time (days)')
plt.ylabel('MSE')
plt.title('MSE vs Time Step for Each Filter')
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis() 
plt.show()
average_mse_per_filter = {filter_name: np.mean(mse_vs_time[filter_name]) for filter_name in filter_names}

average_mse_per_filter
# Out:
# (2424, 71, 3)
# (2424, 71, 3)
# {'ztfg': 0.14669520833032174,
#  'ztfr': 0.13332608765406584,
#  'ztfi': 0.0781426778178753}
