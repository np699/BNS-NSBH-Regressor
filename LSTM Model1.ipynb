# %% [markdown]
# # Imports

# %%
from keras.regularizers import l1_l2
from keras.layers import BatchNormalization
from keras.layers import Bidirectional
from sklearn.utils import shuffle
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.constraints import max_norm
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
import tensorflow as tf
from joblib import dump, load
from tensorflow.keras import losses

# %% [markdown]
# # Input data (mass ejecta)

# %%
# Load the data
lightCurve = pd.read_csv("/Users/np699/Library/CloudStorage/OneDrive-DrexelUniversity/Untitled Folder/Forecaster/lightcurveDataCom7988.csv")
features = pd.read_csv("/Users/np699/Library/CloudStorage/OneDrive-DrexelUniversity/Untitled Folder/Forecaster/featureDataCom7988_ejectaA.csv")


# Drop unnecessary columns from the features dataframe
features = features.drop(["simulation_id", 'far', 'snr'], axis=1)

# Filter the light curve data
filtered_df = lightCurve[lightCurve['filter'].isin(['ztfg', 'ztfr', 'ztfi'])].copy()
filtered_df = filtered_df[['filter', 'mag']]

num_light_curves = features.shape[0]

# Ensure the data is in the correct order
filter_order = ['ztfg', 'ztfr', 'ztfi']
filtered_df['filter'] = pd.Categorical(filtered_df['filter'], categories=filter_order, ordered=True)
filtered_df = filtered_df.sort_index()

# Consistency check
total_points = len(filtered_df)
if total_points % (num_light_curves * len(filter_order)) != 0:
    raise ValueError("The number of data points is not divisible by the number of light curves times the number of filters.")

num_time_points = total_points // (num_light_curves * len(filter_order))

# Reshape the data
y = np.empty((num_light_curves, num_time_points * len(filter_order)), dtype=filtered_df['mag'].dtype)
ztfg_mags = filtered_df[filtered_df['filter'] == 'ztfg']['mag'].values.reshape(num_light_curves, num_time_points)
ztfr_mags = filtered_df[filtered_df['filter'] == 'ztfr']['mag'].values.reshape(num_light_curves, num_time_points)
ztfi_mags = filtered_df[filtered_df['filter'] == 'ztfi']['mag'].values.reshape(num_light_curves, num_time_points)

# Populate reshaped array
for i in range(num_time_points):
    y[:, i * 3 + 0] = ztfg_mags[:, i]
    y[:, i * 3 + 1] = ztfr_mags[:, i]
    y[:, i * 3 + 2] = ztfi_mags[:, i]

# Time array
t_min = 0.1
t_max = 14.0
dt = 0.2
time_single = np.linspace(t_min, t_max, num_time_points)

# Standardize the feature data
feature_scaler = StandardScaler()
X = feature_scaler.fit_transform(features)

# Standardize the target data
target_scaler = StandardScaler()
y = target_scaler.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Reshape y data for LSTM input
y_train_reshaped = y_train.reshape((y_train.shape[0], num_time_points, len(filter_order)))
y_test_reshaped = y_test.reshape((y_test.shape[0], num_time_points, len(filter_order)))

# Reshape X data for LSTM input
X_train_reshaped = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %% [markdown]
# # Model

# %%
# Define the LSTM model
model = Sequential()

# First Bidirectional LSTM Layer with Batch Normalization and Dropout
model.add(Bidirectional(LSTM(150, activation='relu', return_sequences=True,
                             kernel_regularizer=l1_l2(l1=0.001, l2=0.01),
                             kernel_constraint=max_norm(3.0),
                        input_shape=(1, X_train.shape[1]))))
model.add(BatchNormalization())
model.add(Dropout(0.1))

# Second Bidirectional LSTM Layer with Batch Normalization
model.add(Bidirectional(LSTM(100, activation='relu', return_sequences=False,
                             kernel_regularizer=l1_l2(l1=0.001, l2=0.01),
                             kernel_constraint=max_norm(3.0)
                             )))
model.add(BatchNormalization())
model.add(Dropout(0.1))

# Dense output layer
model.add(Dense(213))
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Training

# %%
# Compile the model with a lower learning rate and gradient clipping
optimizer = Adam(learning_rate=0.0003, clipnorm=1.0)  # Only clipnorm is used
model.compile(optimizer=optimizer, loss='mse')

# Implement early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-6)

# Train the model
history = model.fit(X_train_reshaped, y_train, 
                    epochs=300, batch_size=64, validation_split=0.3, 
                    verbose=1, callbacks=[early_stopping, lr_reduction])

# Save the trained model
#dump(model, 'Com7988_ejectaA.joblib')
# Out:
# Epoch 1/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 18.3796 - val_loss: 13.2617 - learning_rate: 3.0000e-04
# Epoch 2/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.4367 - val_loss: 8.4432 - learning_rate: 3.0000e-04
# Epoch 3/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.9367 - val_loss: 5.2215 - learning_rate: 3.0000e-04
# Epoch 4/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9458 - val_loss: 3.1792 - learning_rate: 3.0000e-04
# Epoch 5/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1010 - val_loss: 1.9887 - learning_rate: 3.0000e-04
# Epoch 6/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0622 - val_loss: 1.3829 - learning_rate: 3.0000e-04
# Epoch 7/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5945 - val_loss: 1.1514 - learning_rate: 3.0000e-04
# Epoch 8/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4446 - val_loss: 0.9275 - learning_rate: 3.0000e-04
# Epoch 9/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3591 - val_loss: 0.7639 - learning_rate: 3.0000e-04
# Epoch 10/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.3150 - val_loss: 0.6055 - learning_rate: 3.0000e-04
# Epoch 11/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2944 - val_loss: 0.4413 - learning_rate: 3.0000e-04
# Epoch 12/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2759 - val_loss: 0.3374 - learning_rate: 3.0000e-04
# Epoch 13/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2647 - val_loss: 0.2713 - learning_rate: 3.0000e-04
# Epoch 14/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2421 - val_loss: 0.2495 - learning_rate: 3.0000e-04
# Epoch 15/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2362 - val_loss: 0.2315 - learning_rate: 3.0000e-04
# Epoch 16/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2278 - val_loss: 0.2052 - learning_rate: 3.0000e-04
# Epoch 17/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2211 - val_loss: 0.2105 - learning_rate: 3.0000e-04
# Epoch 18/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2190 - val_loss: 0.1860 - learning_rate: 3.0000e-04
# Epoch 19/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2144 - val_loss: 0.1878 - learning_rate: 3.0000e-04
# Epoch 20/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1992 - val_loss: 0.1886 - learning_rate: 3.0000e-04
# Epoch 21/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2011 - val_loss: 0.1805 - learning_rate: 3.0000e-04
# Epoch 22/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1977 - val_loss: 0.1879 - learning_rate: 3.0000e-04
# Epoch 23/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2116 - val_loss: 0.1751 - learning_rate: 3.0000e-04
# Epoch 24/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2051 - val_loss: 0.1865 - learning_rate: 3.0000e-04
# Epoch 25/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1899 - val_loss: 0.1701 - learning_rate: 3.0000e-04
# Epoch 26/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1885 - val_loss: 0.1719 - learning_rate: 3.0000e-04
# Epoch 27/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1944 - val_loss: 0.1712 - learning_rate: 3.0000e-04
# Epoch 28/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1924 - val_loss: 0.1666 - learning_rate: 3.0000e-04
# Epoch 29/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1802 - val_loss: 0.1641 - learning_rate: 3.0000e-04
# Epoch 30/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1886 - val_loss: 0.1701 - learning_rate: 3.0000e-04
# Epoch 31/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1800 - val_loss: 0.1673 - learning_rate: 3.0000e-04
# Epoch 32/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1886 - val_loss: 0.1702 - learning_rate: 3.0000e-04
# Epoch 33/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1860 - val_loss: 0.1646 - learning_rate: 3.0000e-04
# Epoch 34/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1787 - val_loss: 0.1653 - learning_rate: 3.0000e-04
# Epoch 35/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1751 - val_loss: 0.1571 - learning_rate: 1.5000e-04
# Epoch 36/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1806 - val_loss: 0.1584 - learning_rate: 1.5000e-04
# Epoch 37/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1785 - val_loss: 0.1552 - learning_rate: 1.5000e-04
# Epoch 38/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1801 - val_loss: 0.1546 - learning_rate: 1.5000e-04
# Epoch 39/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1658 - val_loss: 0.1539 - learning_rate: 1.5000e-04
# Epoch 40/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1771 - val_loss: 0.1538 - learning_rate: 1.5000e-04
# Epoch 41/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1779 - val_loss: 0.1538 - learning_rate: 1.5000e-04
# Epoch 42/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1662 - val_loss: 0.1530 - learning_rate: 1.5000e-04
# Epoch 43/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1702 - val_loss: 0.1532 - learning_rate: 1.5000e-04
# Epoch 44/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1789 - val_loss: 0.1517 - learning_rate: 1.5000e-04
# Epoch 45/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1675 - val_loss: 0.1527 - learning_rate: 1.5000e-04
# Epoch 46/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1739 - val_loss: 0.1525 - learning_rate: 1.5000e-04
# Epoch 47/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1641 - val_loss: 0.1535 - learning_rate: 1.5000e-04
# Epoch 48/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1629 - val_loss: 0.1625 - learning_rate: 1.5000e-04
# Epoch 49/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1720 - val_loss: 0.1528 - learning_rate: 1.5000e-04
# Epoch 50/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1656 - val_loss: 0.1480 - learning_rate: 7.5000e-05
# Epoch 51/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1599 - val_loss: 0.1481 - learning_rate: 7.5000e-05
# Epoch 52/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1658 - val_loss: 0.1479 - learning_rate: 7.5000e-05
# Epoch 53/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1642 - val_loss: 0.1493 - learning_rate: 7.5000e-05
# Epoch 54/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1688 - val_loss: 0.1493 - learning_rate: 7.5000e-05
# Epoch 55/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1611 - val_loss: 0.1476 - learning_rate: 7.5000e-05
# Epoch 56/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1722 - val_loss: 0.1480 - learning_rate: 7.5000e-05
# Epoch 57/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1683 - val_loss: 0.1474 - learning_rate: 7.5000e-05
# Epoch 58/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1654 - val_loss: 0.1465 - learning_rate: 7.5000e-05
# Epoch 59/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1628 - val_loss: 0.1486 - learning_rate: 7.5000e-05
# Epoch 60/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1622 - val_loss: 0.1465 - learning_rate: 7.5000e-05
# Epoch 61/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1695 - val_loss: 0.1463 - learning_rate: 7.5000e-05
# Epoch 62/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1604 - val_loss: 0.1456 - learning_rate: 7.5000e-05
# Epoch 63/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1606 - val_loss: 0.1454 - learning_rate: 7.5000e-05
# Epoch 64/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1724 - val_loss: 0.1465 - learning_rate: 7.5000e-05
# Epoch 65/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1621 - val_loss: 0.1450 - learning_rate: 7.5000e-05
# Epoch 66/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1634 - val_loss: 0.1452 - learning_rate: 7.5000e-05
# Epoch 67/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1594 - val_loss: 0.1452 - learning_rate: 7.5000e-05
# Epoch 68/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1567 - val_loss: 0.1449 - learning_rate: 7.5000e-05
# Epoch 69/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1640 - val_loss: 0.1451 - learning_rate: 7.5000e-05
# Epoch 70/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1554 - val_loss: 0.1452 - learning_rate: 7.5000e-05
# Epoch 71/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1737 - val_loss: 0.1447 - learning_rate: 7.5000e-05
# Epoch 72/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1563 - val_loss: 0.1442 - learning_rate: 7.5000e-05
# Epoch 73/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1632 - val_loss: 0.1470 - learning_rate: 7.5000e-05
# Epoch 74/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1595 - val_loss: 0.1459 - learning_rate: 7.5000e-05
# Epoch 75/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1684 - val_loss: 0.1447 - learning_rate: 7.5000e-05
# Epoch 76/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1654 - val_loss: 0.1458 - learning_rate: 7.5000e-05
# Epoch 77/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1579 - val_loss: 0.1445 - learning_rate: 7.5000e-05
# Epoch 78/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1561 - val_loss: 0.1422 - learning_rate: 3.7500e-05
# Epoch 79/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1713 - val_loss: 0.1421 - learning_rate: 3.7500e-05
# Epoch 80/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1607 - val_loss: 0.1417 - learning_rate: 3.7500e-05
# Epoch 81/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1545 - val_loss: 0.1420 - learning_rate: 3.7500e-05
# Epoch 82/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1644 - val_loss: 0.1433 - learning_rate: 3.7500e-05
# Epoch 83/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1627 - val_loss: 0.1416 - learning_rate: 3.7500e-05
# Epoch 84/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1581 - val_loss: 0.1416 - learning_rate: 3.7500e-05
# Epoch 85/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1618 - val_loss: 0.1414 - learning_rate: 3.7500e-05
# Epoch 86/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1514 - val_loss: 0.1414 - learning_rate: 3.7500e-05
# Epoch 87/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1684 - val_loss: 0.1414 - learning_rate: 3.7500e-05
# Epoch 88/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1600 - val_loss: 0.1410 - learning_rate: 3.7500e-05
# Epoch 89/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1580 - val_loss: 0.1415 - learning_rate: 3.7500e-05
# Epoch 90/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1615 - val_loss: 0.1415 - learning_rate: 3.7500e-05
# Epoch 91/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1641 - val_loss: 0.1420 - learning_rate: 3.7500e-05
# Epoch 92/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1616 - val_loss: 0.1410 - learning_rate: 3.7500e-05
# Epoch 93/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1511 - val_loss: 0.1411 - learning_rate: 3.7500e-05
# Epoch 94/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1561 - val_loss: 0.1404 - learning_rate: 1.8750e-05
# Epoch 95/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1592 - val_loss: 0.1402 - learning_rate: 1.8750e-05
# Epoch 96/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1573 - val_loss: 0.1401 - learning_rate: 1.8750e-05
# Epoch 97/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1669 - val_loss: 0.1402 - learning_rate: 1.8750e-05
# Epoch 98/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1529 - val_loss: 0.1401 - learning_rate: 1.8750e-05
# Epoch 99/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1567 - val_loss: 0.1402 - learning_rate: 1.8750e-05
# Epoch 100/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1655 - val_loss: 0.1402 - learning_rate: 1.8750e-05
# Epoch 101/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1529 - val_loss: 0.1402 - learning_rate: 1.8750e-05
# Epoch 102/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1550 - val_loss: 0.1397 - learning_rate: 9.3750e-06
# Epoch 103/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1574 - val_loss: 0.1396 - learning_rate: 9.3750e-06
# Epoch 104/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1542 - val_loss: 0.1396 - learning_rate: 9.3750e-06
# Epoch 105/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1548 - val_loss: 0.1395 - learning_rate: 9.3750e-06
# Epoch 106/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1571 - val_loss: 0.1394 - learning_rate: 9.3750e-06
# Epoch 107/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1576 - val_loss: 0.1396 - learning_rate: 9.3750e-06
# Epoch 108/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1534 - val_loss: 0.1395 - learning_rate: 9.3750e-06
# Epoch 109/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1524 - val_loss: 0.1395 - learning_rate: 9.3750e-06
# Epoch 110/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1618 - val_loss: 0.1394 - learning_rate: 9.3750e-06
# Epoch 111/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1573 - val_loss: 0.1393 - learning_rate: 4.6875e-06
# Epoch 112/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1560 - val_loss: 0.1393 - learning_rate: 4.6875e-06
# Epoch 113/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1565 - val_loss: 0.1392 - learning_rate: 4.6875e-06
# Epoch 114/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1597 - val_loss: 0.1392 - learning_rate: 4.6875e-06
# Epoch 115/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1626 - val_loss: 0.1392 - learning_rate: 4.6875e-06
# Epoch 116/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1583 - val_loss: 0.1392 - learning_rate: 4.6875e-06
# Epoch 117/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1576 - val_loss: 0.1391 - learning_rate: 2.3438e-06
# Epoch 118/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1563 - val_loss: 0.1390 - learning_rate: 2.3438e-06
# Epoch 119/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1542 - val_loss: 0.1390 - learning_rate: 2.3438e-06
# Epoch 120/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1516 - val_loss: 0.1389 - learning_rate: 2.3438e-06
# Epoch 121/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1552 - val_loss: 0.1390 - learning_rate: 2.3438e-06
# Epoch 122/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1536 - val_loss: 0.1390 - learning_rate: 2.3438e-06
# Epoch 123/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1626 - val_loss: 0.1391 - learning_rate: 2.3438e-06
# Epoch 124/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1533 - val_loss: 0.1391 - learning_rate: 2.3438e-06
# Epoch 125/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1612 - val_loss: 0.1390 - learning_rate: 2.3438e-06
# Epoch 126/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1525 - val_loss: 0.1389 - learning_rate: 1.1719e-06
# Epoch 127/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1549 - val_loss: 0.1390 - learning_rate: 1.1719e-06
# Epoch 128/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1541 - val_loss: 0.1390 - learning_rate: 1.1719e-06
# Epoch 129/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1583 - val_loss: 0.1390 - learning_rate: 1.1719e-06
# Epoch 130/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1499 - val_loss: 0.1390 - learning_rate: 1.1719e-06
# Epoch 131/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1613 - val_loss: 0.1390 - learning_rate: 1.0000e-06
# Epoch 132/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1486 - val_loss: 0.1390 - learning_rate: 1.0000e-06
# Epoch 133/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1573 - val_loss: 0.1390 - learning_rate: 1.0000e-06
# Epoch 134/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1589 - val_loss: 0.1390 - learning_rate: 1.0000e-06
# Epoch 135/300
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1549 - val_loss: 0.1389 - learning_rate: 1.0000e-06

# %% [markdown]
# # Predictions

# %%
# MC Dropout function for prediction with uncertainty
def predict_with_uncertainty(model, X, n_iter=1000):
    """
    Perform MC Dropout predictions with TensorFlow 2.x.
    
    Args:
    - model: The Keras model with dropout layers.
    - X: Input data to make predictions on.
    - n_iter: Number of forward passes to perform.
    
    Returns:
    - mean_preds: Mean predictions.
    - uncertainty: Standard deviation of predictions (uncertainty).
    """
    
    # Perform n_iter forward passes and collect the predictions
    preds = [model(X, training=True) for _ in range(n_iter)]  # Dropout active during inference
    preds = np.array(preds)
    
    # Calculate mean and standard deviation of the predictions
    mean_preds = preds.mean(axis=0)
    uncertainty = preds.std(axis=0)
    
    return mean_preds, uncertainty

# Perform MC Dropout to predict with uncertainty
n_mc_samples = 1000  # Number of forward passes
mean_preds, uncertainty = predict_with_uncertainty(model, X_test_reshaped, n_iter=n_mc_samples)

# Reshape the mean predictions to match the shape used during scaling (num_samples, num_time_points * num_filters)
mean_preds_flat = mean_preds.reshape(mean_preds.shape[0], num_time_points * len(filter_order))  
# Invert the standardization for the mean predictions
mean_preds_inverted = target_scaler.inverse_transform(mean_preds_flat).reshape(mean_preds.shape[0], num_time_points, len(filter_order))

# Reshape uncertainty to match mean_preds_inverted shape
uncertainty_reshaped = uncertainty.reshape(uncertainty.shape[0], num_time_points, len(filter_order))
# Evaluate the model using the mean predictions
print(mean_preds_flat.flatten().shape)
test_mse_mc = mean_squared_error(y_test.flatten(), mean_preds_flat.flatten())
test_r2_mc = r2_score(y_test.flatten(), mean_preds_flat.flatten())
print(test_mse_mc.shape)
print(f'Test MSE with MC Dropout: {test_mse_mc:.4f}, Test R² with MC Dropout: {test_r2_mc:.4f}')
mae = np.mean(np.abs(y_test.flatten() - mean_preds_flat.flatten()))
print(mae)

# Plot the learning curve
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve')
plt.legend()
plt.show()
# Out:
# (516312,)
# ()
# Test MSE with MC Dropout: 0.1236, Test R² with MC Dropout: 0.8828
# 0.26176733679508973

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Time points for plotting
time_points = np.tile(time_single, (X_test_reshaped.shape[0], 1))

# Invert the scaling for y_test to compare with predictions

y_test_inverted = target_scaler.inverse_transform(y_test.reshape(y_test.shape[0], -1)).reshape((y_test.shape[0], num_time_points, len(filter_order)))
mse_per_curve = np.mean((y_test_inverted - mean_preds_inverted) ** 2, axis=(1, 2))  # MSE for each light curve across all time points and filters

mse_target = 0.12
tolerance = 0.1  # Define a tolerance level to find light curves with MSE close to 3.6
selected_index = np.where(np.abs(mse_per_curve - mse_target) < tolerance)[0]  # Get the indices of the light curves that meet the condition

if len(selected_index) > 0:
    # Select the first light curve that matches the criteria
    example_idx = selected_index[0]

    # Step 3: Plot the selected light curve
    plt.figure(figsize=(10, 6))
    filter_names = ['ztfg', 'ztfr', 'ztfi']
    colors = {'ztfg': 'green', 'ztfr': 'red', 'ztfi': 'blue'}

    # Plot the ZTFg, ZTFr, and ZTFi filters separately for the selected light curve
    mean_curve = mean_preds_inverted[example_idx]
    true_curve = y_test_inverted[example_idx]

    # Loop over each filter
    for i, filter_name in enumerate(filter_names):
        plt.plot(time_single, mean_curve[:, i], label=f'Predicted {filter_name}', color=colors[filter_name])
        plt.fill_between(time_single, 
                         mean_curve[:, i] - 5 * uncertainty_reshaped[example_idx, :, i], 
                         mean_curve[:, i] + 5 * uncertainty_reshaped[example_idx, :, i], 
                         color=colors[filter_name], alpha=0.2, label=f'Uncertainty {filter_name}')

        # Plot the true values for comparison
        plt.plot(time_single, true_curve[:, i], '--', color=colors[filter_name], label=f'True {filter_name}')

    # Add labels and title
    plt.xlabel('Time (days)')
    plt.ylabel('Magnitude')
    plt.gca().invert_yaxis()  # Invert the y-axis for magnitude, since lower magnitude means brighter
    plt.title(f'Light Curve with MSE ~ {mse_target} (Light Curve Index: {example_idx})')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print(f"No light curve found with MSE close to {mse_target}.")

# %%
# Loop over each filter to calculate peak magnitudes and MSE per curve
for i, filter_name in enumerate(filter_names):
    # Calculate the minimum value (peak magnitude) for the current filter
    peak_magnitudes_filter = np.min(y_test_inverted[:, :, i], axis=1)  # Shape (num_samples,)
    
    # Calculate MSE for the current filter
    mse_per_curve_filter = np.mean((y_test_inverted[:, :, i] - mean_preds_inverted[:, :, i]) ** 2, axis=1)  # Shape (num_samples,)
    
    # Ensure both arrays have the same length
    assert peak_magnitudes_filter.shape == mse_per_curve_filter.shape, f"Shapes of peak magnitudes and MSE do not match for filter {filter_name}!"

    # Step 2: Create 3D histogram (binning the data) for each filter with MSE limited between 0 and 5
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Plot a 3D histogram for the current filter, now MSE on the x-axis and Peak Magnitude on the y-axis
    hist, xedges, yedges = np.histogram2d(mse_per_curve_filter, peak_magnitudes_filter, bins=10, range=[[0, 1], [np.min(peak_magnitudes_filter), np.max(peak_magnitudes_filter)]])

    # Construct arrays for the 3D histogram bars
    xpos, ypos = np.meshgrid(xedges[:-1] + 0.5 * (xedges[1:] - xedges[:-1]),
                             yedges[:-1] + 0.5 * (yedges[1:] - yedges[:-1]), indexing="ij")

    xpos = xpos.ravel()
    ypos = ypos.ravel()
    zpos = 0

    # Set the width and depth for the bars
    dx = dy = 0.1 * np.ones_like(zpos)
    dz = hist.ravel()

    # Plot the bars
    ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average', color=colors[filter_names[i]], alpha=0.7)

    # Set labels and title
    ax.set_xlabel('MSE (limited between 0 and 5)')
    ax.set_ylabel('Peak Magnitude (min)')
    ax.set_zlabel('Number of Light Curves')
    ax.set_title(f'3D Histogram of MSE vs Number of Light Curves vs Peak Magnitude for {filter_name}')

    plt.show()

# %%
# Loop over each filter and compute MSE at each time step
mse_vs_time = {}
filter_names = ['ztfg', 'ztfr', 'ztfi']
colors = {'ztfg': 'green', 'ztfr': 'red', 'ztfi': 'blue'}
y_test_reshaped = y_test.reshape(y_test.shape[0], num_time_points, len(filter_order)) 
print(y_test_reshaped.shape)
mean_preds_reshaped = mean_preds.reshape(mean_preds.shape[0], num_time_points, len(filter_order)) 
print(mean_preds_reshaped.shape)
for i, filter_name in enumerate(filter_names):
    # Calculate MSE at each time step (averaged across all light curves)
    mse_per_time_step = np.mean((y_test_reshaped[:,:,i] - mean_preds_reshaped[:,:,i]) ** 2, axis=0)  
    
    mse_vs_time[filter_name] = mse_per_time_step

plt.figure(figsize=(10, 6))

for filter_name in filter_names:
    plt.plot(time_single, mse_vs_time[filter_name], label=f'MSE for {filter_name}', color=colors[filter_name])

# Add labels and title
plt.xlabel('Time (days)')
plt.ylabel('MSE')
plt.title('MSE vs Time Step for Each Filter')
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis() 
plt.show()
average_mse_per_filter = {filter_name: np.mean(mse_vs_time[filter_name]) for filter_name in filter_names}

average_mse_per_filter
# Out:
# (2424, 71, 3)
# (2424, 71, 3)
# {'ztfg': 0.15216329885493202,
#  'ztfr': 0.13711004935888513,
#  'ztfi': 0.0814322778816913}
